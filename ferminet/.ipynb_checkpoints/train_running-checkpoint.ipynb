# %%
import sys

from absl import logging
from ferminet.utils import system
from ferminet import base_config
from ferminet import train
from ferminet.configs import atom

# Optional, for also printing training progress to STDOUT.
# If running a script, you can also just use the --alsologtostderr flag.
logging.get_absl_handler().python_handler.stream = sys.stdout
logging.set_verbosity(logging.INFO)


# Define H2 molecule
cfg = base_config.default()
cfg.system.electrons = (1,1)  # (alpha electrons, beta electrons)
cfg.system.molecule = [system.Atom('H', (0, 0, -1)), system.Atom('H', (0, 0, 1))]

# Set training parameters
cfg.batch_size = 4096
cfg.pretrain.iterations = 0
cfg.mcmc.burn_in = 0
cfg.optim.optimizer = 'minsr'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
evaluate_loss, mcmc_step, sharded_key, data, params, mcmc_width, logabs_network = train.train(cfg, wandb_monitoring=False)
# Out:
# cfg.optim.optimizer = 'minsr'
# INFO:absl:Starting QMC with 1 XLA devices per host across 1 hosts.
# INFO:absl:No checkpoint found. Training new model.
# INFO:absl:Burning in MCMC chain for 0 steps
# INFO:absl:Completed burn-in MCMC steps
# INFO:absl:Initial energy: 1.2318 E_h

# %% [markdown]
# ### Constructing Grunter through streaming gradients

# %%
import jax
import jax.numpy as jnp
from jax import tree_util
import gc
from tqdm.notebook import tqdm

# %%
from ferminet import constants

# %%
# squeezing pmap dimension to work on 1 gpu
data_positions = jnp.squeeze(data.positions, axis=0)
data_spins = jnp.squeeze(data.spins, axis=0)
data_atoms = jnp.squeeze(data.atoms, axis=0)
data_charges = jnp.squeeze(data.charges, axis=0)
params_ = jax.tree.map(lambda x: jnp.squeeze(x, axis=0), params)

# %%
batch_network = jax.vmap(
      logabs_network, in_axes=(None, 0, 0, 0, 0), out_axes=0
  ) # Multi sample network output

grad_params = jax.grad(logabs_network, argnums=0)  # Single sample grad wrt model output

batch_network_grad = jax.vmap(
      grad_params, in_axes=(None, 0, 0, 0, 0), out_axes=0
  )  # Multi sample grad wrt model output (memory problems very quickly)

# %%
def params_to_array(params_pytree, batched=False):
    leaves, _ = jax.tree_util.tree_flatten(params_pytree)
    if batched:
        batch_size = leaves[0].shape[0]
        flat_leaves = [jnp.reshape(leaf, (batch_size, -1)) for leaf in leaves]
        return jnp.concatenate(flat_leaves, axis=1)  # Shape: (batch_size, n_params)
    else:
        return jnp.concatenate([jnp.ravel(leaf) for leaf in leaves], axis=0)

# %%
def clear_memory():
    jax.clear_caches()
    gc.collect()
    jax.device_put(jax.numpy.zeros(1)).block_until_ready()

# %%
grad_params = val_grad(params_, data_positions[0], data_spins[0], data_atoms[0], data_charges[0])

# %%
# Testing grad param time estimates
n_samples = 4096
for i in tqdm(range(n_samples)):
    grad_params = val_grad(params_, data_positions[i], data_spins[i], data_atoms[i], data_charges[i])

# %%
clear_memory()

# %%
# limits of batched based gradients
n_samples = 64

param_grads = batch_network_grad(
    params_, data_positions[:n_samples], data_spins[:n_samples], data_atoms[:n_samples], data_charges[:n_samples])

# %%
import jax.numpy as jnp

arr = jnp.zeros((3,3))

# %%
import jax.numpy as jnp

x = jnp.zeros((3, 3))
x = x.at[1, 2].add(10)

# %%
x
# Out:
# Array([[ 0.,  0.,  0.],
#        [ 0.,  0., 10.],
#        [ 0.,  0.,  0.]], dtype=float32)

# %%
data_positions[0]
# Out:
# Array([-0.30012602, -0.86698204,  1.7608517 , -0.05705162, -1.9491963 ,
#        -0.31753278], dtype=float32)

# %%
def get_batch_network_gradients(pos_start, pos_end):
    return batch_network_grad(
        params_,
        data_positions[pos_start:pos_end], data_spins[pos_start: pos_end], data_atoms[pos_start: pos_end], data_charges[pos_start: pos_end])

# %%
def A(x, n_params):
    """ Takes in the vector x (N_samples) and uses it as a premultiplier for the gradients """
    output_vec = jnp.zeros(n_params)

    minibatch = 64
    for i in range(0, n_samples, minibatch):
        pos_start = i * minibatch
        pos_end = i * minibatch + minibatch
        output_vec = output_vec.at[:].add(
            get_batch_network_gradients(pos_start, pos_end) @ x[pos_start:pos_end])

    return output_vec

# %%
grads_0 = get_batch_network_gradients(0,32)

# %%
flat_grads_0 = params_to_array(grads_0, batched=True)

# %%
flat_grads_0.shape
# Out:
# (32, 667104)

# %%
flat_grads_0.T @ x[:32]
# Out:
# 2025-08-12 13:01:48.721239: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 81.43MiB (rounded to 85389312)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-08-12 13:01:48.721548: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ****************************************************************************************************
# E0812 13:01:48.721565    1515 pjrt_stream_executor_client.cc:2939] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 85389312 bytes. [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 flat_grads_0.T @ x[:32]
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:437, in _transpose_property(self)
#     432 def _transpose_property(self: Array):
#     433   """Compute the all-axis array transpose.
#     434
#     435   Refer to :func:`jax.numpy.transpose` for details.
#     436   """
# --> 437   return lax_numpy.transpose(self)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:1199, in transpose(a, axes)
#    1197 axes_ = list(range(a.ndim)[::-1]) if axes is None else axes
#    1198 axes_ = [_canonicalize_axis(i, np.ndim(a)) for i in axes_]
# -> 1199 return lax.transpose(a, axes_)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/lax/lax.py:2918, in transpose(operand, permutation)
#    2915   return operand
#    2916 else:
# -> 2918   return transpose_p.bind(operand, permutation=permutation)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/core.py:576, in Primitive.bind(self, *args, **params)
#     574 def bind(self, *args, **params):
#     575   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 576   return self._true_bind(*args, **params)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/core.py:592, in Primitive._true_bind(self, *args, **params)
#     590 trace_ctx.set_trace(eval_trace)
#     591 try:
# --> 592   return self.bind_with_trace(prev_trace, args, params)
#     593 finally:
#     594   trace_ctx.set_trace(prev_trace)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/core.py:602, in Primitive.bind_with_trace(self, trace, args, params)
#     599   with set_current_trace(trace):
#     600     return self.to_lojax(*args, **params)  # type: ignore
# --> 602 return trace.process_primitive(self, args, params)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/core.py:1126, in EvalTrace.process_primitive(self, primitive, args, params)
#    1124 args = map(full_lower, args)
#    1125 check_eval_args(args)
# -> 1126 return primitive.impl(*args, **params)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/dispatch.py:91, in apply_primitive(prim, *args, **params)
#      89 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      90 try:
# ---> 91   outs = fun(*args)
#      92 finally:
#      93   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 5 frame]
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1305, in ExecuteReplicated.__call__(self, *args)
#    1303   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1304 else:
# -> 1305   results = self.xla_executable.execute_sharded(input_bufs)
#    1307 if dispatch.needs_check_special():
#    1308   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 85389312 bytes.

# %%
n_params = flat_grads_0.shape[1]
key = jax.random.PRNGKey(0)
n = 4096
x = jax.random.normal(key, shape=(n,))
output_vec = jnp.zeros(n_params)

minibatch = 4
for i in tqdm(range(0, n, minibatch)):
    pos_start = i * minibatch
    pos_end = i * minibatch + minibatch
    output_vec = output_vec.at[:].add(
        params_to_array(get_batch_network_gradients(pos_start, pos_end), batched=True).T @ x[pos_start:pos_end])
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# 2025-08-12 13:02:37.454667: W external/xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.03MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[65], line 12
#       9 pos_start = i * minibatch
#      10 pos_end = i * minibatch + minibatch
#      11 output_vec = output_vec.at[:].add(
# ---> 12     params_to_array(get_batch_network_gradients(pos_start, pos_end), batched=True).T @ x[pos_start:pos_end])
#
# Cell In[55], line 2, in get_batch_network_gradients(pos_start, pos_end)
#       1 def get_batch_network_gradients(pos_start, pos_end):
# ----> 2     return batch_network_grad(
#       3         params_,
#       4         data_positions[pos_start:pos_end], data_spins[pos_start: pos_end], data_atoms[pos_start: pos_end], data_charges[pos_start: pos_end])
#
#     [... skipping hidden 19 frame]
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/train.py:744, in train.<locals>.<lambda>(*args, **kwargs)
#     739     logabs_network = utils.select_output(
#     740         networks.make_total_ansatz(signed_network,
#     741                                    cfg.system.get('states', 0),
#     742                                    complex_output=use_complex), 1)
#     743 else:
# --> 744   logabs_network = lambda *args, **kwargs: signed_network(*args, **kwargs)[1]
#     745 batch_network = jax.vmap(
#     746     logabs_network, in_axes=(None, 0, 0, 0, 0), out_axes=0
#     747 )  # batched network
#     749 # Exclusively when computing the gradient wrt the energy for complex
#     750 # wavefunctions, it is necessary to have log(psi) rather than log(|psi|).
#     751 # This is unused if the wavefunction is real-valued.
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/networks.py:1507, in make_fermi_net.<locals>.apply(params, pos, spins, atoms, charges)
#    1486 def apply(
#    1487     params,
#    1488     pos: jnp.ndarray,
#    (...)   1491     charges: jnp.ndarray,
#    1492 ) -> Tuple[jnp.ndarray, jnp.ndarray]:
#    1493   """Forward evaluation of the Fermionic Neural Network for a single datum.
#    1494
#    1495   Args:
#    (...)   1504     of and log absolute of the network evaluated at x.
#    1505   """
# -> 1507   orbitals = orbitals_apply(params, pos, spins, atoms, charges)
#    1508   if options.states:
#    1509     batch_logdet_matmul = jax.vmap(network_blocks.logdet_matmul, in_axes=0)
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/networks.py:1173, in make_orbitals.<locals>.apply(params, pos, spins, atoms, charges)
#    1158 """Forward evaluation of the Fermionic Neural Network up to the orbitals.
#    1159
#    1160 Args:
#    (...)   1170   nalpha+nbeta) (or (ndet, nalpha, nalpha) and (ndet, nbeta, nbeta)).
#    1171 """
#    1172 ae, ee, r_ae, r_ee = construct_input_features(pos, atoms, ndim=options.ndim)
# -> 1173 h_to_orbitals = equivariant_layers_apply(
#    1174     params['layers'],
#    1175     ae=ae,
#    1176     r_ae=r_ae,
#    1177     ee=ee,
#    1178     r_ee=r_ee,
#    1179     spins=spins,
#    1180     charges=charges,
#    1181 )
#    1183 if options.envelope.apply_type == envelopes.EnvelopeType.PRE_ORBITAL:
#    1184   envelope_factor = options.envelope.apply(
#    1185       ae=ae, r_ae=r_ae, r_ee=r_ee, **params['envelope']
#    1186   )
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/networks.py:1030, in make_fermi_net_layers.<locals>.apply(***failed resolving arguments***)
#    1027   nuclear_embedding = None
#    1029 for i in range(len(options.hidden_dims)):
# -> 1030   h_one, h_two, h_elec_ion = apply_layer(
#    1031       params['streams'][i],
#    1032       h_one,
#    1033       h_two,
#    1034       h_elec_ion,
#    1035       nuclear_embedding,
#    1036   )
#    1038 if options.use_last_layer:
#    1039   last_layer = params['streams'][-1]
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/networks.py:944, in make_fermi_net_layers.<locals>.apply_layer(params, h_one, h_two, h_elec_ion, nuclear_embedding)
#     938 h_one_in = construct_symmetric_features(
#     939     h_one, h_two_embedding, nspins, h_aux=h_aux
#     940 )
#     942 # Execute next layer.
#     943 h_one_next = jnp.tanh(
# --> 944     network_blocks.linear_layer(h_one_in, **params['single'])
#     945 )
#     946 h_one = residual(h_one, h_one_next)
#     947 # Only perform the auxiliary streams if parameters are present (ie not the
#     948 # final layer of the network if use_last_layer is False).
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/ferminet/ferminet/network_blocks.py:103, in linear_layer(x, w, b)
#      90 def linear_layer(x: jnp.ndarray,
#      91                  w: jnp.ndarray,
#      92                  b: Optional[jnp.ndarray] = None) -> jnp.ndarray:
#      93   """Evaluates a linear layer, x w + b.
#      94
#      95   Args:
#    (...)    101     x w + b if b is given, x w otherwise.
#     102   """
# --> 103   y = jnp.dot(x, w)
#     104   return y + b if b is not None else y
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/numpy/tensor_contractions.py:120, in dot(a, b, precision, preferred_element_type, out_sharding)
#     118   else:
#     119     contract_dims = ((a_ndim - 1,), (b_ndim - 2,))
# --> 120 result = lax.dot_general(a, b, dimension_numbers=(contract_dims, batch_dims),
#     121                          precision=precision,
#     122                          preferred_element_type=preferred_element_type,
#     123                          out_sharding=out_sharding)
#     124 return lax._convert_element_type(result, preferred_element_type,
#     125                                  output_weak_type)
#
#     [... skipping hidden 41 frame]
#
# File /mnt/c/Users/Parv/Doc/RA/Projects/QVMC/fermi/lib/python3.12/site-packages/jax/_src/compiler.py:377, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     368       return backend.compile_and_load(
#     369           built_c,
#     370           executable_devices=executable_devices,
#     371           compile_options=options,
#     372           host_callbacks=host_callbacks,
#     373       )
#     374     # Some backends don't have `host_callbacks` option yet
#     375     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     376     # to take in `host_callbacks`
# --> 377     return backend.compile_and_load(
#     378         built_c,
#     379         executable_devices=executable_devices,
#     380         compile_options=options,
#     381     )
#     382 except xc.XlaRuntimeError as e:
#     383   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16811008 bytes.
